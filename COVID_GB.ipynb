# %%
# import libraries 
import pandas as pd # Import Pandas for data manipulation using dataframes
import numpy as np # Import Numpy for data statistical analysis 
import matplotlib.pyplot as plt # Import matplotlib for data visualisation
import random
import seaborn as sns
from fbprophet import Prophet

# %%
covid=pd.read_csv("Daily_Cases_By_Province.csv")
covid.columns.values
# Out:
# array(['Date', 'AJK', 'Balochistan', 'KPK', 'GB', 'Sindh', 'Punjab',
#        'ICT'], dtype=object)

# %%
covid_GB=covid[['Date','GB']]
covid_GB=covid_GB.rename(columns={'Date':'ds','GB':'y'})
covid_GB['y']=covid_GB['y'].diff()
covid_GB['y']=covid_GB['y'].fillna(0)
model=Prophet()
model.fit(covid_GB)
month = model.make_future_dataframe(periods=30)
forecast_month = model.predict(month)
month_figure=model.plot(forecast_month,xlabel='Date',ylabel='Cases Per Day')
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\khana\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning:
#
# Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.

# %%
covid_GB
# Out:
#            ds     y
# 0   10-Mar-20   0.0
# 1   11-Mar-20   1.0
# 2   12-Mar-20   0.0
# 3   13-Mar-20   0.0
# 4   14-Mar-20   0.0
# 5   15-Mar-20   0.0
# 6   16-Mar-20   0.0
# 7   17-Mar-20   0.0
# 8   18-Mar-20  10.0
# 9   19-Mar-20   8.0
# 10  20-Mar-20   9.0
# 11  21-Mar-20  25.0
# 12  22-Mar-20  16.0
# 13  23-Mar-20   9.0
# 14  24-Mar-20   1.0
# 15  25-Mar-20   3.0
# 16  26-Mar-20   7.0
# 17  27-Mar-20  16.0
# 18  28-Mar-20   9.0
# 19  29-Mar-20  12.0
# 20  30-Mar-20  20.0
# 21  31-Mar-20  36.0
# 22   1-Apr-20   3.0
# 23   2-Apr-20   3.0
# 24   3-Apr-20   3.0
# 25   4-Apr-20  13.0
# 26   5-Apr-20   4.0
# 27   6-Apr-20   1.0
# 28   7-Apr-20   1.0
# 29   8-Apr-20   1.0
# 30   9-Apr-20   2.0
# 31  10-Apr-20   0.0
# 32  11-Apr-20   1.0
# 33  12-Apr-20   8.0
# 34  13-Apr-20   9.0
# 35  14-Apr-20   1.0
# 36  15-Apr-20   3.0
# 37  16-Apr-20   8.0
# 38  17-Apr-20   5.0
# 39  18-Apr-20   7.0
# 40  19-Apr-20   6.0
# 41  20-Apr-20  18.0
# 42  21-Apr-20   0.0
# 43  22-Apr-20   9.0
# 44  23-Apr-20   0.0
